# %%
import pandas as pd
import numpy as np
df = pd.read_csv('C:\\Users\\meerz\\OneDrive\\Desktop\\DataSets\\yellow (1).csv')

# %%
df
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2     15-01-2015 19:05      15-01-2015 19:23                1
# 1              1      10/1/2015 20:33       10/1/2015 20:53                1
# 2              1      10/1/2015 20:33       10/1/2015 20:43                1
# 3              1      10/1/2015 20:33       10/1/2015 20:35                1
# 4              1      10/1/2015 20:33       10/1/2015 20:52                1
# ...          ...                  ...                   ...              ...
# 524630         1     29-01-2015 23:08      29-01-2015 23:37                1
# 524631         1     29-01-2015 23:08      29-01-2015 23:27                1
# 524632         1     29-01-2015 23:08      29-01-2015 23:15                2
# 524633         2     23-01-2015 01:53      23-01-2015 02:09                1
# 524634         2     23-01-2015 01:53      23-01-2015 02:07                3
#
# ...

# %%
df.shape
# Out:
# (524635, 19)

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RateCodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          2     15-01-2015 19:05      15-01-2015 19:23                1
# 1          1      10/1/2015 20:33       10/1/2015 20:53                1
# 2          1      10/1/2015 20:33       10/1/2015 20:43                1
# 3          1      10/1/2015 20:33       10/1/2015 20:35                1
# 4          1      10/1/2015 20:33       10/1/2015 20:52                1
# 5          1      10/1/2015 20:33       10/1/2015 20:53                1
# 6          1      10/1/2015 20:33       10/1/2015 20:58                1
# 7          1      10/1/2015 20:33       10/1/2015 20:42                3
# 8          1      10/1/2015 20:33       10/1/2015 21:11                3
# 9          1      10/1/2015 20:33       10/1/2015 20:40                2
# 10         1      10/1/2015 20:33       10/1/2015 20:41                1
# 11         1      10/1/2015 20:33       10/1/2015 20:43                1
# ...

# %%
df["payment_type"].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
df["payment_type"].value_counts()
# Out:
# payment_type
# 1    324316
# 2    198282
# 3      1546
# 4       491
# Name: count, dtype: int64

# %%
df["VendorID"].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df["VendorID"].value_counts()
# Out:
# VendorID
# 2    272214
# 1    252421
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#             VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  524635.000000    524635.000000  524635.000000     524635.000000
# mean        1.518864         1.677080       3.008378        -72.555594
# std         0.499645         1.333957     133.675386         10.147004
# min         1.000000         0.000000       0.000000        -87.451874
# 25%         1.000000         1.000000       1.000000        -73.991676
# 50%         2.000000         1.000000       1.660000        -73.981567
# 75%         2.000000         2.000000       3.000000        -73.966606
# max         2.000000         9.000000   92000.900000          0.000000
#
#        pickup_latitude     RateCodeID  dropoff_longitude  dropoff_latitude  \
# count    524635.000000  524635.000000      524635.000000     524635.000000
# mean         39.969282       1.036810         -72.601932         39.995991
# std           5.590187       0.661161           9.981921          5.498842
# ...

# %%
df.describe().T  #exchange rows and columns
# Out:
#                           count       mean         std         min        25%  \
# VendorID               524635.0   1.518864    0.499645    1.000000   1.000000
# passenger_count        524635.0   1.677080    1.333957    0.000000   1.000000
# trip_distance          524635.0   3.008378  133.675386    0.000000   1.000000
# pickup_longitude       524635.0 -72.555594   10.147004  -87.451874 -73.991676
# pickup_latitude        524635.0  39.969282    5.590187    0.000000  40.735687
# RateCodeID             524635.0   1.036810    0.661161    1.000000   1.000000
# dropoff_longitude      524635.0 -72.601932    9.981921  -86.731705 -73.991219
# dropoff_latitude       524635.0  39.995991    5.498842    0.000000  40.734497
# payment_type           524635.0   1.386644    0.498658    1.000000   1.000000
# fare_amount            524635.0  11.871896   10.120575 -138.900000   6.500000
# extra                  524635.0   0.315220    0.367405   -1.000000   0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 524635 entries, 0 to 524634
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               524635 non-null  int64
#  1   tpep_pickup_datetime   524635 non-null  object
#  2   tpep_dropoff_datetime  524635 non-null  object
#  3   passenger_count        524635 non-null  int64
#  4   trip_distance          524635 non-null  float64
#  5   pickup_longitude       524635 non-null  float64
#  6   pickup_latitude        524635 non-null  float64
#  7   RateCodeID             524635 non-null  int64
#  8   store_and_fwd_flag     524635 non-null  object
#  9   dropoff_longitude      524635 non-null  float64
#  10  dropoff_latitude       524635 non-null  float64
#  11  payment_type           524635 non-null  int64
#  12  fare_amount            524635 non-null  float64
#  13  extra                  524635 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RateCodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  1
# tip_amount               1
# tolls_amount             1
# improvement_surcharge    1
# total_amount             1
# dtype: int64

# %%
df.shape
# Out:
# (524635, 19)

# %%
df.drop_duplicates #remove duplicates from data set
# Out:
# <bound method DataFrame.drop_duplicates of         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2     15-01-2015 19:05      15-01-2015 19:23                1
# 1              1      10/1/2015 20:33       10/1/2015 20:53                1
# 2              1      10/1/2015 20:33       10/1/2015 20:43                1
# 3              1      10/1/2015 20:33       10/1/2015 20:35                1
# 4              1      10/1/2015 20:33       10/1/2015 20:52                1
# ...          ...                  ...                   ...              ...
# 524630         1     29-01-2015 23:08      29-01-2015 23:37                1
# 524631         1     29-01-2015 23:08      29-01-2015 23:27                1
# 524632         1     29-01-2015 23:08      29-01-2015 23:15                2
# 524633         2     23-01-2015 01:53      23-01-2015 02:09                1
# 524634         2     23-01-2015 01:53      23-01-2015 02:07                3
#
# ...

# %%
df.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RateCodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  1
# tip_amount               1
# tolls_amount             1
# improvement_surcharge    1
# total_amount             1
# dtype: int64

# %%
df.shape
# Out:
# (524635, 19)

# %%
df["fare_amount"].drop_duplicates
# Out:
# <bound method Series.drop_duplicates of 0         12.0
# 1         14.5
# 2          9.5
# 3          3.5
# 4         15.0
#           ...
# 524630    21.5
# 524631    15.5
# 524632     6.5
# 524633    16.5
# 524634    18.0
# Name: fare_amount, Length: 524635, dtype: float64>

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RateCodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
df["passenger_count"]
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 524630    1
# 524631    1
# 524632    2
# 524633    1
# 524634    3
# Name: passenger_count, Length: 524635, dtype: int64

# %%
df["tip_amount"]
# Out:
# 0         3.25
# 1         2.00
# 2         0.00
# 3         0.00
# 4         0.00
#           ...
# 524630    4.55
# 524631    0.00
# 524632    1.00
# 524633    0.00
# 524634     NaN
# Name: tip_amount, Length: 524635, dtype: float64

# %%
df["total_amount"]
# Out:
# 0         17.05
# 1         17.80
# 2         10.80
# 3          4.80
# 4         16.30
#           ...
# 524630    27.35
# 524631    16.80
# 524632     8.80
# 524633    17.80
# 524634      NaN
# Name: total_amount, Length: 524635, dtype: float64

# %%
df.groupby("payment_type")["VendorID"].value_counts()
# Out:
# payment_type  VendorID
# 1             2           168886
#               1           155430
# 2             2           103198
#               1            95084
# 3             1             1486
#               2               60
# 4             1              421
#               2               70
# Name: count, dtype: int64

# %%
df.groupby("fare_amount")["mta_tax"].mean()
# Out:
# fare_amount
# -138.90   -0.5
# -68.00    -0.5
# -60.00     0.0
# -52.00    -0.5
# -50.00    -0.5
#           ...
#  370.00    0.0
#  420.00    0.0
#  587.93    0.0
#  665.00    0.0
#  900.00    0.0
# Name: mta_tax, Length: 551, dtype: float64

# %%
df.groupby("total_amount")["tip_amount"].min()
# Out:
# total_amount
# -139.70      0.00
# -116.22    -58.09
# -85.80     -81.00
# -72.46     -14.33
# -68.80       0.00
#             ...
#  453.30     33.00
#  587.93      0.00
#  665.00      0.00
#  802.80    750.00
#  900.30      0.00
# Name: tip_amount, Length: 4230, dtype: float64

# %%
df.groupby("trip_distance")["passenger_count"].max()
# Out:
# trip_distance
# 0.00        9
# 0.01        6
# 0.02        6
# 0.03        6
# 0.04        6
#            ..
# 180.60      1
# 181.40      1
# 400.10      1
# 30083.20    1
# 92000.90    1
# Name: passenger_count, Length: 2614, dtype: int64

# %%
df.groupby("VendorID")["tip_amount"].mean()
# Out:
# VendorID
# 1    1.557279
# 2    1.530661
# Name: tip_amount, dtype: float64

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RateCodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
df[df["total_amount"] == 16]["fare_amount"].value_counts()
# Out:
# fare_amount
# 12.0    268
# 11.5    197
# 11.0    110
# 13.5     71
# 13.0     71
# 12.5     62
# 14.0     42
# 14.5      6
# 12.7      3
# 13.7      3
# 15.0      3
# 14.2      2
# 15.5      2
# 12.2      1
# 14.7      1
# 2.5       1
# 5.5       1
# 15.2      1
# 13.2      1
# 10.5      1
# Name: count, dtype: int64

# %%
df.tail(20)
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 524615         2     28-01-2015 11:50      28-01-2015 12:04                1
# 524616         2        1/1/2015 2:41         1/1/2015 2:59                3
# 524617         2        1/1/2015 2:41         1/1/2015 2:45                5
# 524618         2        1/1/2015 2:41         1/1/2015 3:02                3
# 524619         1        1/1/2015 2:41         1/1/2015 2:45                1
# 524620         1        1/1/2015 2:41         1/1/2015 2:52                1
# 524621         1        1/1/2015 2:41         1/1/2015 2:57                2
# 524622         1        1/1/2015 2:41         1/1/2015 2:55                2
# 524623         2        1/1/2015 2:41         1/1/2015 2:44                2
# 524624         2        1/1/2015 2:41         1/1/2015 2:44                5
# 524625         2        1/1/2015 2:41         1/1/2015 2:51                1
# ...

# %%
df[df["total_amount"] == 4]["fare_amount"].value_counts()
# Out:
# fare_amount
# 3.5    13
# 3.0     4
# 2.5     4
# 4.0     1
# Name: count, dtype: int64
