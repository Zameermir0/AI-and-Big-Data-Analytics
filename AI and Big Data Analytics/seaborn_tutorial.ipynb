# %%
import seaborn as sns

# %%
df = sns.load_dataset("car_crashes")
df_tips = sns.load_dataset("tips")
df_tips
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # Distribution Plot

# %%
sns.distplot(df["not_distracted"],kde = False,bins = 20,color = "purple",rug = True)
# Out:
# C:\Users\meerz\AppData\Local\Temp\ipykernel_5316\3414087647.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["not_distracted"],kde = False,bins = 20,color = "purple",rug = True)
# <Axes: xlabel='not_distracted'>

# %% [markdown]
# # joint Plot

# %%
sns.jointplot(data = df,x ="speeding",y = "alcohol",kind = "reg")

# %% [markdown]
# # KDE Plots

# %%
sns.kdeplot(df["alcohol"]
           )
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df)
# Out:
# C:\Users\meerz\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df_tips,hue = "time",palette = "Blues")
# Out:
# C:\Users\meerz\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Rug Plot

# %%
sns.rugplot(df_tips["tip"])
# Out:
# <Axes: xlabel='tip'>

# %%
sns.distplot(df["total"],kde  = False,bins = 19)
# Out:
# C:\Users\meerz\AppData\Local\Temp\ipykernel_5316\109239275.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total"],kde  = False,bins = 19)
# <Axes: xlabel='total'>

# %%
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
sns.set_style("darkgrid")
sns.jointplot(data = df, x = "speeding",y = "total", kind = "reg")

# %%
sns.barplot(data = df_tips, x = "day",y = "total_bill",hue = "sex")
sns.set_context("talk")

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style("white") 
sns.stripplot(data = df_tips,x = "day", y = "total_bill",hue = "sex",palette = "afmhot")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data = df_tips,x = "sex",y = "total_bill", hue  = "sex")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.lmplot(data = df_tips , x = "size", y= "total_bill", hue  = "sex")
# Out:
# C:\Users\meerz\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\meerz\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(data = df_tips)
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(data = df_tips,x = "day",y = "total_bill", hue  = "sex",)
import matplotlib.pyplot as plt
plt.legend(loc = 2)

# %%
sns.violinplot(data = df_tips,x = "day",y = "total_bill",split = True,hue  = "sex")
plt.figure(figsize=(160,56))
plt.show()

# %%
sns.stripplot(data = df_tips,x = "day",y = "total_bill",hue  = "sex", jitter = True, dodge = True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
dff = sns.load_dataset("flights")

# %%
dff
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.violinplot(data = dff, x="month" , y = "year")
sns.swarmplot(data = dff, x="month" , y = "year", color = "blue")
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.pairplot(dff)
# Out:
# C:\Users\meerz\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd

# %%
df.drop("abbrev", axis = 1, inplace = True)

# %%
hel = df.corr()

# %%
sns.heatmap(hel,annot = True, cmap = "Blues",linecolor= "white",linewidth = 1.7)
# Out:
# <Axes: >

# %%
df_flights = sns.load_dataset("flights")

# %%
df_flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = df_flights.pivot_table(index = "month",columns = "year",values = "passengers")

# %%
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights, cmap = "Blues",linecolor = "white",linewidth = 1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights, standard_scale = 1)

# %%
sns.PairGrid(df)

# %%
df_iris = sns.load_dataset("iris")

# %%
s = sns.PairGrid(df_iris, hue = "species")
s.map_upper(plt.bar)
s.map_lower(plt.scatter)
s.map_diag(plt.hist)
