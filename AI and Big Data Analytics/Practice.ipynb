# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\meerz\\Downloads\\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["PassengerId"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df["SibSp"] ==5]["Name"]
# Out:
# 59     Goodwin, Master. William Frederick
# 71             Goodwin, Miss. Lillian Amy
# 386       Goodwin, Master. Sidney Leonard
# 480        Goodwin, Master. Harold Victor
# 683           Goodwin, Mr. Charles Edward
# Name: Name, dtype: object

# %%
df.groupby("Pclass")["Age"].value_counts()
# Out:
# Pclass  Age
# 1       35.00    9
#         36.00    9
#         24.00    7
#         38.00    6
#         30.00    6
#                 ..
# 3       14.50    1
#         13.00    1
#         12.00    1
#         0.42     1
#         74.00    1
# Name: count, Length: 182, dtype: int64

# %%
df.groupby("Sex")['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
df.groupby("Sex")['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby("Sex")['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.groupby("Sex")["SibSp"].value_counts()
# Out:
# Sex     SibSp
# female  0        174
#         1        106
#         2         13
#         3         11
#         4          6
#         8          3
#         5          1
# male    0        434
#         1        103
#         2         15
#         4         12
#         3          5
#         5          4
#         8          4
# Name: count, dtype: int64

# %%
df.groupby("Sex")["SibSp"].mean()
# Out:
# Sex
# female    0.694268
# male      0.429809
# Name: SibSp, dtype: float64

# %%
df.groupby('Survived')['Parch'].value_counts()
# Out:
# Survived  Parch
# 0         0        445
#           1         53
#           2         40
#           4          4
#           5          4
#           3          2
#           6          1
# 1         0        233
#           1         65
#           2         40
#           3          3
#           5          1
# Name: count, dtype: int64

# %%
df["Parch"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: Parch, Length: 891, dtype: int64

# %%
df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.groupby("Sex")["Age"].min()
# Out:
# Sex
# female    0.75
# male      0.42
# Name: Age, dtype: float64

# %%
df.groupby("Survived")["Age"].min()
# Out:
# Survived
# 0    1.00
# 1    0.42
# Name: Age, dtype: float64

# %%
df[df["Age"]==1]["Name"]
# Out:
# 164       Panula, Master. Eino Viljami
# 172       Johnson, Miss. Eleanor Ileen
# 183          Becker, Master. Richard F
# 381        Nakid, Miss. Maria ("Mary")
# 386    Goodwin, Master. Sidney Leonard
# 788         Dean, Master. Bertram Vere
# 827              Mallet, Master. Andre
# Name: Name, dtype: object

# %%
df[df["Age"]==80]["Name"]
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df.groupby("Sex")["Age"].max()
# Out:
# Sex
# female    63.0
# male      80.0
# Name: Age, dtype: float64

# %%
df[df["Age"]==63]["Name"]
# Out:
# 275    Andrews, Miss. Kornelia Theodosia
# 483               Turkula, Mrs. (Hedwig)
# Name: Name, dtype: object

# %%
df.groupby("Sex")["Pclass"].sum()
# Out:
# Sex
# female     678
# male      1379
# Name: Pclass, dtype: int64

# %%
df.groupby("Sex")["Pclass"].value_counts()
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: count, dtype: int64

# %%
df.groupby("Pclass")["Survived"].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
df.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df.groupby("Pclass")["Sex"].value_counts()
# Out:
# Pclass  Sex
# 1       male      122
#         female     94
# 2       male      108
#         female     76
# 3       male      347
#         female    144
# Name: count, dtype: int64

# %%
dff = pd.read_csv("C:\\Users\\meerz\\Downloads\\archive//Automobile data.csv")

# %%
dff.describe()
# Out:
#        Engine Size        Bore      Stroke  Compression Ratio  Horse Power  \
# count   205.000000  205.000000  205.000000         205.000000   205.000000
# mean    126.907317    3.326634    3.256488          10.142537   104.292683
# std      41.642693    0.271748    0.313688           3.972040    39.520933
# min      61.000000    2.540000    2.070000           7.000000    48.000000
# 25%      97.000000    3.150000    3.110000           8.600000    70.000000
# 50%     120.000000    3.310000    3.290000           9.000000    95.000000
# 75%     141.000000    3.580000    3.410000           9.400000   116.000000
# max     326.000000    3.940000    4.170000          23.000000   288.000000
#
#            Top-RPM  City Mileage  Highway Mileage  Price in Dollars
# count   205.000000    205.000000       205.000000        205.000000
# mean   5126.068293     25.219512        30.751220      16088.580488
# std     477.031307      6.542142         6.886443      40486.372656
# ...

# %%
dff.head(50)
# Out:
#      Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0   alfa-romero       gas        std        two  convertible         rwd
# 1   alfa-romero       gas        std        two  convertible         rwd
# 2   alfa-romero       gas        std        two    hatchback         rwd
# 3          audi       gas        std       four        sedan         fwd
# 4          audi       gas        std       four        sedan         4wd
# 5          audi       gas        std        two        sedan         fwd
# 6          audi       gas        std       four        sedan         fwd
# 7          audi       gas        std       four        wagon         fwd
# 8          audi       gas      turbo       four        sedan         fwd
# 9          audi       gas      turbo        two    hatchback         4wd
# 10          bmw       gas        std        two        sedan         rwd
# 11          bmw       gas        std       four        sedan         rwd
# ...

# %%
dff.columns
# Out:
# Index(['Brand Name', 'Fuel type', 'Aspiration', 'Door Panel', 'Design',
#        'Wheel Drive', 'Engine Location', 'Engine Type', 'Cylinder Count',
#        'Engine Size', 'Fuel System', 'Bore', 'Stroke', 'Compression Ratio',
#        'Horse Power', 'Top-RPM', 'City Mileage', 'Highway Mileage',
#        'Price in Dollars'],
#       dtype='object')

# %%
dff["Fuel type"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
dff["Price in Dollars"].value_counts()
# Out:
# Price in Dollars
# 8921     2
# 18150    2
# 8495     2
# 7775     2
# 8845     2
#         ..
# 40960    1
# 45400    1
# 16503    1
# 5389     1
# 22625    1
# Name: count, Length: 190, dtype: int64

# %%
dff["City Mileage"].value_counts()
# Out:
# City Mileage
# 31    28
# 19    27
# 24    22
# 27    14
# 17    13
# 26    12
# 23    12
# 21     8
# 25     8
# 30     8
# 38     7
# 28     7
# 16     6
# 37     6
# 22     4
# 29     3
# 15     3
# 20     3
# 18     3
# 14     2
# 34     1
# 35     1
# 32     1
# 36     1
# 45     1
# 13     1
# 49     1
# 47     1
# 33     1
# Name: count, dtype: int64

# %%
dff.groupby("Brand Name")["City Mileage"].value_counts()
# Out:
# Brand Name   City Mileage
# alfa-romero  21              2
#              19              1
# audi         19              3
#              16              1
#              17              1
#                             ..
# volvo        24              2
#              19              2
#              17              2
#              18              1
#              26              1
# Name: count, Length: 96, dtype: int64

# %%
dff.groupby("Brand Name")["Engine Size"].value_counts()
# Out:
# Brand Name   Engine Size
# alfa-romero  130            2
#              152            1
# audi         136            4
#              131            2
#              109            1
#                            ..
# volkswagen   136            1
# volvo        141            7
#              130            2
#              145            1
#              173            1
# Name: count, Length: 70, dtype: int64

# %%
dff["Brand Name"].head(50)
# Out:
# 0     alfa-romero
# 1     alfa-romero
# 2     alfa-romero
# 3            audi
# 4            audi
# 5            audi
# 6            audi
# 7            audi
# 8            audi
# 9            audi
# 10            bmw
# 11            bmw
# 12            bmw
# 13            bmw
# 14            bmw
# 15            bmw
# 16            bmw
# 17            bmw
# 18      chevrolet
# 19      chevrolet
# 20      chevrolet
# 21          dodge
# 22          dodge
# 23          dodge
# 24          dodge
# 25          dodge
# 26          dodge
# 27          dodge
# 28          dodge
# 29          dodge
# 30          honda
# 31          honda
# 32          honda
# 33          honda
# 34          honda
# 35          honda
# 36          honda
# 37          honda
# 38          honda
# 39          honda
# 40          honda
# 41          honda
# 42          honda
# 43          isuzu
# 44          isuzu
# 45          isuzu
# 46          isuzu
# 47         jaguar
# 48         jaguar
# 49         jaguar
# ...

# %%
dff["Brand Name"].value_counts()
# Out:
# Brand Name
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
dff.groupby("Brand Name")["Engine Type"].value_counts()
# Out:
# Brand Name     Engine Type
# alfa-romero    dohc            2
#                ohcv            1
# audi           ohc             7
# bmw            ohc             8
# chevrolet      ohc             2
#                l               1
# dodge          ohc             9
# honda          ohc            13
# isuzu          ohc             4
# jaguar         dohc            2
#                ohcv            1
# mazda          ohc            13
#                rotor           4
# mercedes-benz  ohc             4
#                ohcv            4
# mercury        ohc             1
# mitsubishi     ohc            13
# nissan         ohc            12
#                ohcv            6
# peugot         l              11
# plymouth       ohc             7
# porsche        ohcf            3
#                ohc             1
#                dohcv           1
# renault        ohc             2
# saab           ohc             4
#                dohc            2
# ...

# %%
dff.isnull().sum()
# Out:
# Brand Name           0
# Fuel type            0
# Aspiration           0
# Door Panel           0
# Design               0
# Wheel Drive          0
# Engine Location      0
# Engine Type          0
# Cylinder Count       0
# Engine Size          0
# Fuel System          0
# Bore                 0
# Stroke               0
# Compression Ratio    0
# Horse Power          0
# Top-RPM              0
# City Mileage         0
# Highway Mileage      0
# Price in Dollars     0
# dtype: int64

# %%
dff.groupby("Price in Dollars").sum()
# Out:
#                      Brand Name Fuel type Aspiration Door Panel       Design  \
# Price in Dollars
# 5118                     subaru       gas        std        two    hatchback
# 5151                  chevrolet       gas        std        two    hatchback
# 5195                      mazda       gas        std        two    hatchback
# 5348                     toyota       gas        std        two    hatchback
# 5389                 mitsubishi       gas        std        two    hatchback
# ...                         ...       ...        ...        ...          ...
# 37028                   porsche       gas        std        two  convertible
# 40960             mercedes-benz       gas        std       four        sedan
# 41315                       bmw       gas        std        two        sedan
# 45400             mercedes-benz       gas        std        two      hardtop
# 581758                    isuzu       gas        std        two        sedan
#
# ...

# %%
dff.columns
# Out:
# Index(['Brand Name', 'Fuel type', 'Aspiration', 'Door Panel', 'Design',
#        'Wheel Drive', 'Engine Location', 'Engine Type', 'Cylinder Count',
#        'Engine Size', 'Fuel System', 'Bore', 'Stroke', 'Compression Ratio',
#        'Horse Power', 'Top-RPM', 'City Mileage', 'Highway Mileage',
#        'Price in Dollars'],
#       dtype='object')

# %%
dff.groupby("Engine Location")["Horse Power"].value_counts()
# Out:
# Engine Location  Horse Power
# front            68             19
#                  70             11
#                  69             10
#                  116             9
#                  110             8
#                  95              7
#                  62              6
#                  101             6
#                  88              6
#                  114             6
#                  160             6
#                  97              5
#                  76              5
#                  82              5
#                  84              5
#                  102             5
#                  145             5
#                  111             4
#                  86              4
#                  92              4
#                  123             4
#                  182             3
#                  121             3
#                  152             3
#                  73              3
#                  90              3
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
