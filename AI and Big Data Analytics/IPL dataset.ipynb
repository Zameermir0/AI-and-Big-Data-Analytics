# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\meerz\\Downloads\\matches.csv")

# %%
df.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.shape
# Out:
# (636, 18)

# %%
df["winner"].value_counts().idxmax() #most sucessfull team
# Out:
# 'Mumbai Indians'

# %%
df["player_of_match"].value_counts().idxmax()
# Out:
# 'CH Gayle'

# %%
df["win_by_runs"].idxmax()
# Out:
# 43

# %%
df[df["win_by_runs"]==146]["winner"]
# Out:
# 43    Mumbai Indians
# Name: winner, dtype: object

# %%
df["win_by_wickets"].max()
# Out:
# 10

# %%
df[df["win_by_wickets"]==10]["winner"]
# Out:
# 2            Kolkata Knight Riders
# 34                 Kings XI Punjab
# 71                 Deccan Chargers
# 119               Delhi Daredevils
# 183    Royal Challengers Bangalore
# 298               Rajasthan Royals
# 376                 Mumbai Indians
# 390            Chennai Super Kings
# 542    Royal Challengers Bangalore
# 590            Sunrisers Hyderabad
# Name: winner, dtype: object

# %%
df["win_by_runs"].min()
# Out:
# 0

# %%
df[df["win_by_runs"]==0]
# Out:
#       id  season           city        date                   team1  \
# 1      2    2017           Pune  2017-04-06          Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5      6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..   ...     ...            ...         ...                     ...
# 628  629    2016  Visakhapatnam  2016-05-21         Kings XI Punjab
# 629  630    2016         Kanpur  2016-05-21          Mumbai Indians
# 631  632    2016         Raipur  2016-05-22        Delhi Daredevils
# 632  633    2016      Bangalore  2016-05-24           Gujarat Lions
# 634  635    2016          Delhi  2016-05-27           Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df["win_by_wickets"].min()==1
# Out:
# False

# %%
df[df["win_by_wickets"]==0]
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 13    14    2017        Kolkata  2017-04-15        Kolkata Knight Riders
# 14    15    2017          Delhi  2017-04-15             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 625  626    2016      Bangalore  2016-05-18  Royal Challengers Bangalore
# 630  631    2016        Kolkata  2016-05-22        Kolkata Knight Riders
# 633  634    2016          Delhi  2016-05-25          Sunrisers Hyderabad
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.groupby("toss_winner")["winner"].value_counts().max()
# Out:
# 48

# %%
df.groupby("winner")["win_by_runs"].min()
# Out:
# winner
# Chennai Super Kings            0
# Deccan Chargers                0
# Delhi Daredevils               0
# Gujarat Lions                  0
# Kings XI Punjab                0
# Kochi Tuskers Kerala           0
# Kolkata Knight Riders          0
# Mumbai Indians                 0
# Pune Warriors                  0
# Rajasthan Royals               0
# Rising Pune Supergiant         0
# Rising Pune Supergiants        0
# Royal Challengers Bangalore    0
# Sunrisers Hyderabad            0
# Name: win_by_runs, dtype: int64

# %% [markdown]
# df.columns

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.groupby("toss_decision")["winner"].value_counts()
# Out:
# toss_decision  winner
# bat            Chennai Super Kings            50
#                Mumbai Indians                 41
#                Kolkata Knight Riders          34
#                Rajasthan Royals               30
#                Delhi Daredevils               28
#                Royal Challengers Bangalore    26
#                Kings XI Punjab                20
#                Sunrisers Hyderabad            16
#                Deccan Chargers                14
#                Pune Warriors                   9
#                Rising Pune Supergiants         2
#                Gujarat Lions                   2
# field          Mumbai Indians                 51
#                Kings XI Punjab                50
#                Royal Challengers Bangalore    47
#                Kolkata Knight Riders          43
#                Delhi Daredevils               34
#                Rajasthan Royals               33
#                Chennai Super Kings            29
# ...

# %%
df["toss_decision"].unique()
# Out:
# array(['field', 'bat'], dtype=object)

# %%
df.groupby("winner")["toss_decision"].value_counts()
# Out:
# winner                       toss_decision
# Chennai Super Kings          bat              50
#                              field            29
# Deccan Chargers              field            15
#                              bat              14
# Delhi Daredevils             field            34
#                              bat              28
# Gujarat Lions                field            11
#                              bat               2
# Kings XI Punjab              field            50
#                              bat              20
# Kochi Tuskers Kerala         field             6
# Kolkata Knight Riders        field            43
#                              bat              34
# Mumbai Indians               field            51
#                              bat              41
# Pune Warriors                bat               9
#                              field             3
# Rajasthan Royals             field            33
# ...

# %%
x = df["toss_decision"]=='feild'

# %%
y = x[x['winner']] = x["toss_decision"]

# %%
df[df["win_by_wickets"]!=0]["win_by_wickets"].min()
# Out:
# 1

# %%
df[df["win_by_wickets"]==1]
# Out:
#       id  season     city        date            team1                  team2  \
# 559  560    2015  Kolkata  2015-05-09  Kings XI Punjab  Kolkata Knight Riders
#
#          toss_winner toss_decision  result  dl_applied                 winner  \
# 559  Kings XI Punjab           bat  normal           0  Kolkata Knight Riders
#
#      win_by_runs  win_by_wickets player_of_match         venue       umpire1  \
# 559            0               1      AD Russell  Eden Gardens  AK Chaudhary
#
#              umpire2  umpire3
# 559  HDPK Dharmasena      NaN

# %%
(df["toss_winner"]==df["winner"]).sum()/len(df)*100
# Out:
# 51.100628930817614

# %%
(df["win_by_runs"]!=0).mean()
# Out:
# 0.45125786163522014

# %%
(df["win_by_wickets"]!=0).mean()
# Out:
# 0.5330188679245284
